# %% [markdown]
# 2024-01-04至2024-02-04金价变化

# %%
import pandas as pd

df = pd.read_excel(r"D:\WEIXIN\WeChat_Files\WeChat Files\wxid_kgfl9mzp31do22\FileStorage\File\2024-06\金价\1.4-2.4.xlsx", na_values=["", "NA", "N/A"])
df_cleaned1 = df.dropna()
df_cleaned1 = df_cleaned1[df_cleaned1['Price'] <= 1000]
df_cleaned1['Date'] = pd.to_datetime(df_cleaned1['Date'])
average_prices = df_cleaned1.groupby('Date')['Price'].mean()
print(average_prices)
# Out:
# Date
# 2024-01-04    451.876667
# 2024-01-05    452.282222
# 2024-01-08    451.347778
# 2024-01-09    452.886000
# 2024-01-10    449.792222
# 2024-01-11    445.853750
# 2024-01-12    449.045556
# 2024-01-15    449.242500
# 2024-01-16    449.240000
# 2024-01-17    449.420000
# 2024-01-18    444.407500
# 2024-01-19    446.541250
# 2024-01-22    446.248750
# 2024-01-23    444.968750
# 2024-01-24    444.620000
# 2024-01-25    443.115000
# 2024-01-26    439.224286
# 2024-01-29    445.251250
# 2024-01-30    446.307500
# 2024-01-31    446.520000
# 2024-02-01    446.900000
# 2024-02-02    448.352500
# Name: Price, dtype: float64

# %%
import matplotlib.pyplot as plt
grouped = df_cleaned1.groupby('Date')['Price'].mean().reset_index()
plt.figure(figsize=(15, 6))
plt.plot(grouped['Date'], grouped['Price'], marker='o', linestyle='-') 
plt.title('Average Price Over 1.4-2.4')
plt.xlabel('Date')
plt.ylabel('Average Price') 
plt.grid(True) 
plt.xticks(rotation=45)  
for i, price in enumerate(grouped['Price']):
    plt.text(grouped['Date'][i], price, f'{price:.2f}', ha='right')
plt.tight_layout() 
plt.show()

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

grouped = df_cleaned.groupby('Date')['Price'].mean().reset_index()
date_list = grouped['Date'].tolist()
price_list = grouped['Price'].tolist()

c = (
    Line()
    .add_xaxis(date_list)
    .add_yaxis("Average Price", price_list, is_smooth=True) 
    .set_series_opts(
        areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Average Price Over Time"),
        xaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_align_with_label=False),
            is_scale=False,
            boundary_gap=False,
        ),
    )
    .render_notebook()
)

# %% [markdown]
# 2024-02-04至2024-03-04金价变化

# %%
df = pd.read_excel(r"D:\WEIXIN\WeChat_Files\WeChat Files\wxid_kgfl9mzp31do22\FileStorage\File\2024-06\金价\2.4-3.4.xlsx", na_values=["", "NA", "N/A"])
df_cleaned2 = df.dropna()
df_cleaned2 = df_cleaned2[df_cleaned2['Price'] <= 1000]
df_cleaned2['Date'] = pd.to_datetime(df_cleaned2['Date'])
average_prices = df_cleaned2.groupby('Date')['Price'].mean()
print(average_prices)
# Out:
# Date
# 2024-02-05    481.385
# 2024-02-06    479.675
# 2024-02-07    480.595
# 2024-02-08     481.63
# 2024-02-09    480.615
# 2024-02-19    479.555
# 2024-02-20      479.7
# 2024-02-21    480.235
# 2024-02-22    479.415
# 2024-02-23    478.905
# 2024-02-26    480.465
# 2024-02-27    480.485
# 2024-02-28     480.62
# 2024-02-29    480.955
# 2024-03-01    482.555
# 2024-03-04    488.585
# Name: Price, dtype: object

# %%
grouped = df_cleaned2.groupby('Date')['Price'].mean().reset_index()
plt.figure(figsize=(15, 6))
plt.plot(grouped['Date'], grouped['Price'], marker='o', linestyle='-') 
plt.title('Average Price Over 2.4-3.4')
plt.xlabel('Date')
plt.ylabel('Average Price') 
plt.grid(True) 
plt.xticks(rotation=45) 
for i, price in enumerate(grouped['Price']):
    plt.text(grouped['Date'][i], price, f'{price:.2f}', ha='right')
plt.tight_layout() 
plt.show()

# %% [markdown]
# 2024-03-04至2024-04-04金价变化

# %%
df = pd.read_excel(r"D:\WEIXIN\WeChat_Files\WeChat Files\wxid_kgfl9mzp31do22\FileStorage\File\2024-06\金价\3.4-4.4.xlsx", na_values=["", "NA", "N/A"])
df_cleaned3 = df.dropna()
df_cleaned3 = df_cleaned3[df_cleaned3['Price'] <= 1000]
df_cleaned3['Date'] = pd.to_datetime(df_cleaned3['Date'])
average_prices = df_cleaned3.groupby('Date')['Price'].mean()
print(average_prices)
# Out:
# Date
# 2024-03-04    488.585
# 2024-03-05    494.585
# 2024-03-06     498.52
# 2024-03-07     503.32
# 2024-03-08    504.675
# 2024-03-11     507.56
# 2024-03-12     506.76
# 2024-03-13    504.215
# 2024-03-14     506.42
# 2024-03-15     505.91
# 2024-03-18     503.77
# 2024-03-19    504.565
# 2024-03-20     504.74
# 2024-03-21     512.43
# 2024-03-22    511.195
# 2024-03-25     512.84
# 2024-03-26     513.06
# 2024-03-27    515.325
# 2024-03-28    517.425
# 2024-03-29      526.9
# 2024-04-01    531.915
# 2024-04-02     531.97
# 2024-04-03    538.735
# Name: Price, dtype: object

# %%
grouped = df_cleaned3.groupby('Date')['Price'].mean().reset_index()
plt.figure(figsize=(15, 6))
plt.plot(grouped['Date'], grouped['Price'], marker='o', linestyle='-') 
plt.title('Average Price Over 3.4-4.4')
plt.xlabel('Date')
plt.ylabel('Average Price') 
plt.grid(True) 
plt.xticks(rotation=45)  
for i, price in enumerate(grouped['Price']):
    plt.text(grouped['Date'][i], price, f'{price:.2f}',ha='right')
plt.tight_layout() 
plt.show()

# %% [markdown]
# 2024-04-04至2024-05-04金价变化

# %%
df = pd.read_excel(r"D:\WEIXIN\WeChat_Files\WeChat Files\wxid_kgfl9mzp31do22\FileStorage\File\2024-06\金价\4.4-5.4.xlsx", na_values=["", "NA", "N/A"])
df_cleaned4 = df.dropna()
df_cleaned4 = df_cleaned4[df_cleaned4['Price'] <= 1000]
df_cleaned4['Date'] = pd.to_datetime(df_cleaned4['Date'])
average_prices = df_cleaned4.groupby('Date')['Price'].mean()
print(average_prices)
# Out:
# Date
# 2024-04-08     552.45
# 2024-04-09     555.23
# 2024-04-10    557.175
# 2024-04-11     554.71
# 2024-04-12     564.77
# 2024-04-15    565.625
# 2024-04-16     565.56
# 2024-04-17    565.875
# 2024-04-18    563.415
# 2024-04-19    567.005
# 2024-04-22     560.68
# 2024-04-23    545.875
# 2024-04-24    547.365
# 2024-04-25    547.335
# 2024-04-26    549.945
# 2024-04-29    549.415
# 2024-04-30    547.785
# Name: Price, dtype: object

# %%
grouped = df_cleaned4.groupby('Date')['Price'].mean().reset_index()
plt.figure(figsize=(15, 6))
plt.plot(grouped['Date'], grouped['Price'], marker='o', linestyle='-') 
plt.title('Average Price Over 4.4-5.4')
plt.xlabel('Date')
plt.ylabel('Average Price') 
plt.grid(True) 
plt.xticks(rotation=45)  
for i, price in enumerate(grouped['Price']):
    plt.text(grouped['Date'][i], price, f'{price:.2f}',ha='right')
plt.tight_layout() 
plt.show()

# %% [markdown]
# 2024-05-04至2024-06-04金价变化

# %%
df = pd.read_excel(r"D:\WEIXIN\WeChat_Files\WeChat Files\wxid_kgfl9mzp31do22\FileStorage\File\2024-06\金价\5.4-6.4.xlsx", na_values=["", "NA", "N/A"])
df_cleaned5 = df.dropna()
df_cleaned5 = df_cleaned5[df_cleaned5['Price'] <= 1000]
df_cleaned5['Date'] = pd.to_datetime(df_cleaned5['Date'])
average_prices = df_cleaned5.groupby('Date')['Price'].mean()
print(average_prices)
# Out:
# Date
# 2024-05-06     542.77
# 2024-05-07     545.62
# 2024-05-08     544.44
# 2024-05-09    543.855
# 2024-05-10     550.98
# 2024-05-13    554.125
# 2024-05-14    552.355
# 2024-05-15     555.12
# 2024-05-16    560.245
# 2024-05-17    559.885
# 2024-05-20      572.6
# 2024-05-21    570.755
# 2024-05-22      569.7
# 2024-05-23    558.015
# 2024-05-24    550.235
# 2024-05-27    552.265
# 2024-05-28    554.515
# 2024-05-29     556.06
# 2024-05-30     551.17
# 2024-05-31      552.9
# 2024-06-03    550.075
# 2024-06-04     553.19
# Name: Price, dtype: object

# %%
grouped = df_cleaned5.groupby('Date')['Price'].mean().reset_index()
plt.figure(figsize=(15, 6))
plt.plot(grouped['Date'], grouped['Price'], marker='o', linestyle='-') 
plt.title('Average Price Over 5.4-6.4')
plt.xlabel('Date')
plt.ylabel('Average Price') 
plt.grid(True) 
plt.xticks(rotation=45)  
for i, price in enumerate(grouped['Price']):
    plt.text(grouped['Date'][i], price, f'{price:.2f}',ha='right')
plt.tight_layout() 
plt.show()

# %% [markdown]
# 2024-01-04至2024-06-04金价变化

# %%
import pandas
combined_df = pd.concat([df_cleaned1, df_cleaned2, df_cleaned3, df_cleaned4, df_cleaned5])
average_prices = combined_df.groupby('Date')['Price'].mean()
print(average_prices)
# Out:
# Date
# 2024-01-04    451.876667
# 2024-01-05    452.282222
# 2024-01-08    451.347778
# 2024-01-09       452.886
# 2024-01-10    449.792222
#                  ...
# 2024-05-29        556.06
# 2024-05-30        551.17
# 2024-05-31         552.9
# 2024-06-03       550.075
# 2024-06-04        553.19
# Name: Price, Length: 99, dtype: object

# %%
grouped = combined_df.groupby('Date')['Price'].mean().reset_index()
plt.figure(figsize=(20, 6))
plt.plot(grouped['Date'], grouped['Price'], marker='o', linestyle='-') 
plt.title('Average Price Over 1.4-6.4')
plt.xlabel('Date')
plt.ylabel('Average Price') 
plt.grid(True) 
plt.xticks(rotation=45)  
plt.tight_layout() 
plt.show()

# %%
average_prices.to_csv(r"C:\Users\86183\Desktop\average_prices.csv", header=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

price_df = pd.read_csv(r"C:\Users\86183\Desktop\average_prices.csv")
senti_df = pd.read_csv(r"C:\Users\86183\Desktop\all_senti.csv")
merged_df = pd.merge(price_df, senti_df, on='Date')

correlation = merged_df['Price'].corr(merged_df['Senti'])
plt.scatter(merged_df['Price'], merged_df['Senti'])
plt.title('Scatter plot of Price vs Senti')
plt.xlabel('Price')
plt.ylabel('Senti')
plt.grid(True)
plt.show()

# %%
import pandas as pd

price_df = pd.read_csv(r"C:\Users\86183\Desktop\average_prices.csv")
senti_df = pd.read_csv(r"C:\Users\86183\Desktop\all_senti.csv")

price_df['Date'] = pd.to_datetime(price_df['Date'])
senti_df['Date'] = pd.to_datetime(senti_df['Date'])
merged_df = pd.merge(price_df, senti_df, on='Date', how='inner')

print(merged_df)
# Out:
#          Date       Price  Unnamed: 0     Senti
# 0  2024-01-04  451.876667         297  0.000000
# 1  2024-01-05  452.282222         298  0.000000
# 2  2024-01-08  451.347778         301 -0.221625
# 3  2024-01-09  452.886000         302  0.000000
# 4  2024-01-10  449.792222         303  0.074991
# ..        ...         ...         ...       ...
# 93 2024-05-29  556.060000         423 -0.024830
# 94 2024-05-30  551.170000         424 -0.038838
# 95 2024-05-31  552.900000         425 -0.077276
# 96 2024-06-03  550.075000         428 -0.001206
# 97 2024-06-04  553.190000         429  0.137611
#
# [98 rows x 4 columns]

# %%
correlation = merged_df['Senti'].corr(merged_df['Price'])
print(f"Correlation between senti and price: {correlation}")
# Out:
# Correlation between senti and price: -0.051917264169745896

# %%
import statsmodels.api as sm
X = merged_df['Senti']
y = merged_df['Price']
X = sm.add_constant(X)  # 添加常数项
model = sm.OLS(y, X).fit()
print(model.summary())
plt.scatter(merged_df['Senti'], merged_df['Price'], label='Data Points')
plt.plot(merged_df['Senti'], model.predict(X), color='red', label='Regression Line')
plt.xlabel('Sentiment')
plt.ylabel('Price')
plt.legend()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.2595
# Date:                Wed, 12 Jun 2024   Prob (F-statistic):              0.612
# Time:                        01:04:03   Log-Likelihood:                -508.46
# No. Observations:                  98   AIC:                             1021.
# Df Residuals:                      96   BIC:                             1026.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        509.9828      4.425    115.248      0.000     501.199     518.767
# ...
